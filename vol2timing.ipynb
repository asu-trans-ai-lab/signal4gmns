# %% [markdown]
# <a href="https://colab.research.google.com/github/asu-trans-ai-lab/vol2timing/blob/master/vol2timing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install Vol2timing --upgrade
# Out:
# ...
#      |████████████████████████████████| 61kB 2.5MB/s
# ...
#   Created wheel for Vol2timing: filename=vol2timing-0.0.8-cp37-none-any.whl size=10725 sha256=a69db2bd46348e644159a9271d3d04e838e55288a1a7923946bd8c448c7b5f8a
#   Stored in directory: /root/.cache/pip/wheels/a0/e2/fb/f2b67b0661b772503cfc6e7f399d3395481d5cb37ff8e152c9
# Successfully built Vol2timing
# ...

# %% [markdown]
# Load network data

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-64435dd9-ee6a-4644-9d6b-733341d5075c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64435dd9-ee6a-4644-9d6b-733341d5075c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movement.csv to movement.csv
# User uploaded file "movement.csv" with length 176932 bytes

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fd53a3b2-9440-449d-81f7-f9fcf5dfb7b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd53a3b2-9440-449d-81f7-f9fcf5dfb7b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving node.csv to node (1).csv
# User uploaded file "node.csv" with length 22182 bytes

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-58f0c27d-cd13-4cd4-941f-502bd244b472" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58f0c27d-cd13-4cd4-941f-502bd244b472">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving link.csv to link.csv
# User uploaded file "link.csv" with length 169688 bytes

# %%
from Vol2timing import *

datasetPath_root = r''
Vol2timing("0700_0800", datasetPath_root)
# Out:
# 2021-03-25 21:22:08.513 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - Set Logging System: 2021-03-25 21:22:08.513853
# 2021-03-25 21:22:08.516 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - --Set Global Variable
# 2021-03-25 21:22:08.522 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - --Set Array, Matrix, Dictionary Size
# 2021-03-25 21:22:08.532 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - Initialization Completed!
# 2021-03-25 21:22:08.536 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - Build Main Modual
# 2021-03-25 21:22:08.542 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - --Step 0: Set Working Directory
# 2021-03-25 21:22:08.549 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - --Dataset_Path:root
# 2021-03-25 21:22:08.554 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - Start Iterating
# 2021-03-25 21:22:08.556 | INFO     | Vol2timing.Log4Vol2Timing:info:23 - --Step 1: Load Data
# ...
